# %% [markdown]
# # REST client for PubMed API
#
#
# [Europe PubMed Central](https://europepmc.org/RestfulWebService) offers a REST API.

# %% [markdown]
# For example, http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=p53&format=json gives:
#
#     resultList: {
#         result: [
#             {
#             id: "26174762",
#             pmid: "26174762",
#             title: "Combining intracellular antibodies to restore function of mutated p53 in cancer.",
#             authorString: "Chan G, Jordaan G, Nishimura RN, Weisbart RH.",
#             journalTitle: "Int J Cancer",
#             [...]
#             doi: "10.1002/ijc.29685"
#             }
#             [...]
#         }
#     }
#
# Let's crawl that API programatically:

# %%
import requests # pip install requests

API_BASE = 'http://www.ebi.ac.uk/europepmc/webservices/rest/search?query={}&format=json'
query = 'p53'

res = requests.get(API_BASE.format(query))
json = res.json()
json # print it to see how it looks (what fields are avail.)
# Out:
# {u'hitCount': 150314,
#  u'request': {u'page': 1,
#   u'pageSize': 25,
#   u'query': u'p53',
#   u'resultType': u'lite',
#   u'synonym': False},
#  u'resultList': {u'result': [{u'authorString': u'Chan G, Jordaan G, Nishimura RN, Weisbart RH.',
#     u'citedByCount': 0,
#     u'doi': u'10.1002/ijc.29685',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'26174762',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'1',
#     u'journalIssn': u'0020-7136',
#     u'journalTitle': u'Int J Cancer',
#     u'journalVolume': u'138',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'182-186',
#     u'pmid': u'26174762',
#     u'pubType': u'journal article',
#     u'pubYear': u'2016',
#     u'source': u'MED',
#     u'title': u'Combining intracellular antibodies to restore function of mutated p53 in cancer.'},
#    {u'authorString': u'Cortez MA, Ivan C, Valdecanas D, Wang X, Peltier HJ, Ye Y, Araujo L, Carbone DP, Shilo K, Giri DK, Kelnar K, Martin D, Komaki R, Gomez DR, Krishnan S, Calin GA, Bader AG, Welsh JW.',
#     u'citedByCount': 0,
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'26577528',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'1',
#     u'journalIssn': u'0027-8874',
#     u'journalTitle': u'J Natl Cancer Inst',
#     u'journalVolume': u'108',
#     u'luceneScore': u'NaN',
#     u'pmid': u'26577528',
#     u'pubType': u'journal article',
#     u'pubYear': u'2016',
#     u'source': u'MED',
#     u'title': u'PDL1 Regulation by p53 via miR-34.'},
#    {u'authorString': u'Veneziano L, Barra V, Lentini L, Spatafora S, Di Leonardo A.',
#     u'citedByCount': 1,
#     u'doi': u'10.1002/jcp.24976',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'25752701',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'2',
#     u'journalIssn': u'0021-9541',
#     u'journalTitle': u'J Cell Physiol',
#     u'journalVolume': u'231',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'336-344',
#     u'pmid': u'25752701',
#     u'pubType': u'journal article',
#     u'pubYear': u'2016',
#     u'source': u'MED',
#     u'title': u'p14(ARF) Prevents Proliferation of Aneuploid Cells by Inducing p53-Dependent Apoptosis.'},
#    {u'authorString': u'Xu J, Qian J, Li H, Wu ZS, Shen W, Jia L.',
#     u'citedByCount': 0,
#     u'doi': u'10.1016/j.bios.2015.08.015',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'26291961',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'journalIssn': u'0956-5663',
#     u'journalTitle': u'Biosens Bioelectron',
#     u'journalVolume': u'75',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'41-47',
#     u'pmid': u'26291961',
#     u'pubType': u'journal article',
#     u'pubYear': u'2016',
#     u'source': u'MED',
#     u'title': u'Intelligent DNA machine for the ultrasensitive colorimetric detection of nucleic acids.'},
#    {u'authorString': u'Herraiz C, Calvo F, Pandya P, Cantelli G, Rodriguez-Hernandez I, Orgaz JL, Kang N, Chu T, Sahai E, Sanz-Moreno V.',
#     u'citedByCount': 0,
#     u'doi': u'10.1093/jnci/djv289',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'26464464',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'1',
#     u'journalIssn': u'0027-8874',
#     u'journalTitle': u'J Natl Cancer Inst',
#     u'journalVolume': u'108',
#     u'luceneScore': u'NaN',
#     u'pmid': u'26464464',
#     u'pubType': u'journal article',
#     u'pubYear': u'2016',
#     u'source': u'MED',
#     u'title': u'Reactivation of p53 by a Cytoskeletal Sensor to Control the Balance Between DNA Damage and Tumor Dissemination.'},
#    {u'authorString': u'Duan L, Lei H, Zhang Y, Wan B, Chang J, Feng Q, Huang W.',
#     u'citedByCount': 0,
#     u'doi': u'10.1159/000439123',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'26430901',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'1',
#     u'journalIssn': u'0008-6312',
#     u'journalTitle': u'Cardiology',
#     u'journalVolume': u'133',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'44-53',
#     u'pmid': u'26430901',
#     u'pubType': u'journal article',
#     u'pubYear': u'2016',
#     u'source': u'MED',
#     u'title': u'Calcitonin Gene-Related Peptide Improves Hypoxia-Induced Inflammation and Apoptosis via Nitric Oxide in H9c2 Cardiomyoblast Cells.'},
#    {u'authorString': u'Wang H, Shi H, Yu Q, Chen J, Zhang F, Gao Y.',
#     u'citedByCount': 0,
#     u'doi': u'10.1007/978-3-319-18497-5_10',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'26463923',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'journalIssn': u'0065-1419',
#     u'journalTitle': u'Acta Neurochir Suppl',
#     u'journalVolume': u'121',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'55-61',
#     u'pmid': u'26463923',
#     u'pubType': u'journal article',
#     u'pubYear': u'2016',
#     u'source': u'MED',
#     u'title': u'Sevoflurane Preconditioning Confers Neuroprotection via Anti-apoptosis Effects.'},
#    {u'authorString': u'Shi L, Lei Y, Srivastava R, Qin W, Chen JJ.',
#     u'citedByCount': 0,
#     u'doi': u'10.1002/jmv.24291',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'26059022',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'1',
#     u'journalIssn': u'0146-6615',
#     u'journalTitle': u'J Med Virol',
#     u'journalVolume': u'88',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'127-134',
#     u'pmid': u'26059022',
#     u'pubType': u'journal article',
#     u'pubYear': u'2016',
#     u'source': u'MED',
#     u'title': u'Gallic acid induces apoptosis in human cervical epithelial cells containing human papillomavirus type 16 episomes.'},
#    {u'authorString': u'Ilisso CP, Sapio L, Delle Cave D, Illiano M, Spina A, Cacciapuoti G, Naviglio S, Porcelli M.',
#     u'citedByCount': 0,
#     u'doi': u'10.1002/jcp.25089',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'26174106',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'2',
#     u'journalIssn': u'0021-9541',
#     u'journalTitle': u'J Cell Physiol',
#     u'journalVolume': u'231',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'428-435',
#     u'pmid': u'26174106',
#     u'pubType': u'journal article',
#     u'pubYear': u'2016',
#     u'source': u'MED',
#     u'title': u'S-Adenosylmethionine Affects ERK1/2 and Stat3 Pathways and Induces Apotosis in Osteosarcoma Cells.'},
#    {u'authorString': u'Wu X, He C, Wu Y, Chen X.',
#     u'citedByCount': 0,
#     u'doi': u'10.1016/j.biomaterials.2015.10.016',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'26497429',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'journalIssn': u'0142-9612',
#     u'journalTitle': u'Biomaterials',
#     u'journalVolume': u'75',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'148-162',
#     u'pmid': u'26497429',
#     u'pubType': u'journal article',
#     u'pubYear': u'2016',
#     u'source': u'MED',
#     u'title': u"Synergistic therapeutic effects of Schiff's base cross-linked injectable hydrogels for local co-delivery of metformin and 5-fluorouracil in a mouse colon carcinoma model."},
#    {u'authorString': u'Yang-Hartwich Y, Soteras MG, Lin ZP, Holmberg J, Sumi N, Craveiro V, Liang M, Romanoff E, Bingham J, Garofalo F, Alvero A, Mor G.',
#     u'citedByCount': 0,
#     u'dbCrossReferenceList': {u'dbName': [u'UNIPROT']},
#     u'doi': u'10.1038/onc.2014.296',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'Y',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'25263447',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'27',
#     u'journalIssn': u'0950-9232',
#     u'journalTitle': u'Oncogene',
#     u'journalVolume': u'34',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'3605-3616',
#     u'pmid': u'25263447',
#     u'pubType': u"journal article; research support, non-u.s. gov't; research support, n.i.h., extramural",
#     u'pubYear': u'2015',
#     u'source': u'MED',
#     u'title': u'p53 protein aggregation promotes platinum resistance in ovarian cancer.'},
#    {u'authorString': u'Dong P, Ihira K, Hamada J, Watari H, Yamada T, Hosaka M, Hanley SJ, Kudo M, Sakuragi N.',
#     u'citedByCount': 0,
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'26343523',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'24',
#     u'journalIssn': u'1949-2553',
#     u'journalTitle': u'Oncotarget',
#     u'journalVolume': u'6',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'19968-19975',
#     u'pmid': u'26343523',
#     u'pubType': u'journal article; review',
#     u'pubYear': u'2015',
#     u'source': u'MED',
#     u'title': u'Reactivating p53 functions by suppressing its novel inhibitor iASPP: a potential therapeutic opportunity in p53 wild-type tumors.'},
#    {u'authorString': u'Seipel K, Teixera Marques M, Bozzini MA, Meinken C, Mueller BU, Pabst T.',
#     u'citedByCount': 0,
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'26408402',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'journalIssn': u'1078-0432',
#     u'journalTitle': u'Clin Cancer Res',
#     u'luceneScore': u'NaN',
#     u'pmid': u'26408402',
#     u'pubType': u'journal article',
#     u'pubYear': u'2015',
#     u'source': u'MED',
#     u'title': u'Inactivation of the p53-KLF4-CEBPA axis in acute myeloid leukemia.'},
#    {u'authorString': u'Chao CC.',
#     u'citedByCount': 2,
#     u'doi': u'10.1016/j.cca.2014.08.015',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'25172038',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'journalIssn': u'0009-8981',
#     u'journalTitle': u'Clin Chim Acta',
#     u'journalVolume': u'438',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'139-147',
#     u'pmid': u'25172038',
#     u'pubType': u"journal article; review; research support, non-u.s. gov't",
#     u'pubYear': u'2015',
#     u'source': u'MED',
#     u'title': u'Mechanisms of p53 degradation.'},
#    {u'authorString': u'Zhang P, Elabd S, Hammer S, Solozobova V, Yan H, Bartel F, Inoue S, Henrich T, Wittbrodt J, Loosli F, Davidson G, Blattner C.',
#     u'citedByCount': 0,
#     u'doi': u'10.1038/onc.2015.21',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'25728675',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'46',
#     u'journalIssn': u'0950-9232',
#     u'journalTitle': u'Oncogene',
#     u'journalVolume': u'34',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'5729-5738',
#     u'pmid': u'25728675',
#     u'pubType': u'journal article',
#     u'pubYear': u'2015',
#     u'source': u'MED',
#     u'title': u'TRIM25 has a dual function in the p53/Mdm2 circuit.'},
#    {u'authorString': u'Qiu S, Cai Y, Gao X, Gu SZ, Liu ZJ.',
#     u'citedByCount': 0,
#     u'doi': u'10.1016/j.canlet.2014.10.044',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'25444901',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'2 pt b',
#     u'journalIssn': u'0304-3835',
#     u'journalTitle': u'Cancer Lett',
#     u'journalVolume': u'356',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'910-917',
#     u'pmid': u'25444901',
#     u'pubType': u"journal article; research support, non-u.s. gov't",
#     u'pubYear': u'2015',
#     u'source': u'MED',
#     u'title': u'A small peptide derived from p53 linker region can resume the apoptotic activity of p53 by sequestering iASPP with p53.'},
#    {u'authorString': u'Nguyen TT, Hachisuga T, Urabe R, Kurita T, Kagami S, Kawagoe T, Shimajiri S, Nabeshima K.',
#     u'citedByCount': 0,
#     u'dbCrossReferenceList': {u'dbName': [u'UNIPROT']},
#     u'doi': u'10.1007/s00428-015-1752-5',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'Y',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'25788166',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'6',
#     u'journalIssn': u'0945-6317',
#     u'journalTitle': u'Virchows Arch',
#     u'journalVolume': u'466',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'695-702',
#     u'pmid': u'25788166',
#     u'pubType': u'journal article',
#     u'pubYear': u'2015',
#     u'source': u'MED',
#     u'title': u'Significance of p53 expression in background endometrium in endometrial carcinoma.'},
#    {u'authorString': u'Ayroldi E, Petrillo MG, Bastianelli A, Marchetti MC, Ronchetti S, Nocentini G, Ricciotti L, Cannarile L, Riccardi C.',
#     u'citedByCount': 0,
#     u'dbCrossReferenceList': {u'dbName': [u'UNIPROT']},
#     u'doi': u'10.1038/cdd.2014.129',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'Y',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'Y',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'25168242',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'1',
#     u'journalIssn': u'1350-9047',
#     u'journalTitle': u'Cell Death Differ',
#     u'journalVolume': u'22',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'118-130',
#     u'pmid': u'25168242',
#     u'pubType': u"journal article; research support, non-u.s. gov't",
#     u'pubYear': u'2015',
#     u'source': u'MED',
#     u'title': u'L-GILZ binds p53 and MDM2 and suppresses tumor growth through p53 activation in human cancer cells.'},
#    {u'authorString': u'He XX, Zhang YN, Yan JW, Yan JJ, Wu Q, Song YH.',
#     u'citedByCount': 0,
#     u'doi': u'10.1007/s13277-015-3857-5',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'26250460',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'journalIssn': u'1010-4283',
#     u'journalTitle': u'Tumour Biol',
#     u'luceneScore': u'NaN',
#     u'pmid': u'26250460',
#     u'pubType': u'journal article',
#     u'pubYear': u'2015',
#     u'source': u'MED',
#     u'title': u'CP-31398 inhibits the growth of p53-mutated liver cancer cells in vitro and in vivo.'},
#    {u'authorString': u'Tonelli C, Morelli MJ, Bianchi S, Rotta L, Capra T, Sab\xf2 A, Campaner S, Amati B.',
#     u'citedByCount': 0,
#     u'doi': u'10.18632/oncotarget.5232',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'26372730',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'28',
#     u'journalIssn': u'1949-2553',
#     u'journalTitle': u'Oncotarget',
#     u'journalVolume': u'6',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'24611-24626',
#     u'pmid': u'26372730',
#     u'pubType': u'journal article',
#     u'pubYear': u'2015',
#     u'source': u'MED',
#     u'title': u'Genome-wide analysis of p53 transcriptional programs in B cells upon exposure to genotoxic stress in vivo.'},
#    {u'authorString': u'Yun Z, Glazer PM.',
#     u'citedByCount': 0,
#     u'doi': u'10.1172/jci82058',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'25961449',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'6',
#     u'journalIssn': u'0021-9738',
#     u'journalTitle': u'J Clin Invest',
#     u'journalVolume': u'125',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'2264-2266',
#     u'pmid': u'25961449',
#     u'pubType': u'comment; journal article; research support, n.i.h., extramural',
#     u'pubYear': u'2015',
#     u'source': u'MED',
#     u'title': u'Tumor suppressor p53 stole the AKT in hypoxia.'},
#    {u'authorString': u'Lisachev PD, Pustylnyak VO, Shtark MB.',
#     u'citedByCount': 0,
#     u'doi': u'10.1007/s10517-015-2755-6',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'25573363',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'3',
#     u'journalIssn': u'0007-4888',
#     u'journalTitle': u'Bull Exp Biol Med',
#     u'journalVolume': u'158',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'333-335',
#     u'pmid': u'25573363',
#     u'pubType': u"journal article; research support, non-u.s. gov't",
#     u'pubYear': u'2015',
#     u'source': u'MED',
#     u'title': u'Mdm2-dependent regulation of p53 expression during long-term potentiation.'},
#    {u'authorString': u'Gurpinar E, Vousden KH.',
#     u'citedByCount': 0,
#     u'doi': u'10.1016/j.tcb.2015.04.001',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'25960041',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'8',
#     u'journalIssn': u'0962-8924',
#     u'journalTitle': u'Trends Cell Biol',
#     u'journalVolume': u'25',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'486-495',
#     u'pmid': u'25960041',
#     u'pubType': u"journal article; review; research support, non-u.s. gov't",
#     u'pubYear': u'2015',
#     u'source': u'MED',
#     u'title': u"Hitting cancers' weak spots: vulnerabilities imposed by p53 mutation."},
#    {u'authorString': u'Arlt C, Ihling CH, Sinz A.',
#     u'citedByCount': 0,
#     u'doi': u'10.1002/pmic.201400549',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'N',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'25728495',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'16',
#     u'journalIssn': u'1615-9853',
#     u'journalTitle': u'Proteomics',
#     u'journalVolume': u'15',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'2746-2755',
#     u'pmid': u'25728495',
#     u'pubType': u"journal article; research support, non-u.s. gov't",
#     u'pubYear': u'2015',
#     u'source': u'MED',
#     u'title': u'Structure of full-length p53 tumor suppressor probed by chemical cross-linking and mass spectrometry.'},
#    {u'authorString': u'Savorani C, Manf\xe9 V, Biskup E, Gniadecki R.',
#     u'citedByCount': 1,
#     u'doi': u'10.3109/10428194.2014.929673',
#     u'hasBook': u'N',
#     u'hasDbCrossReferences': u'N',
#     u'hasLabsLinks': u'N',
#     u'hasPDF': u'N',
#     u'hasReferences': u'Y',
#     u'hasTMAccessionNumbers': u'N',
#     u'hasTextMinedTerms': u'N',
#     u'id': u'24898668',
#     u'inEPMC': u'N',
#     u'inPMC': u'N',
#     u'issue': u'3',
#     u'journalIssn': u'1042-8194',
#     u'journalTitle': u'Leuk Lymphoma',
#     u'journalVolume': u'56',
#     u'luceneScore': u'NaN',
#     u'pageInfo': u'739-747',
#     u'pmid': u'24898668',
#     u'pubType': u'journal article',
#     u'pubYear': u'2015',
#     u'source': u'MED',
#     u'title': u'Ellipticine induces apoptosis in T-cell lymphoma via oxidative DNA damage.'}]},
#  u'version': u'4.4.0'}

# %%
results = json[u'resultList'][u'result']
for i, r in enumerate(results):
    print i, r['title'][:60], 'http://www.ncbi.nlm.nih.gov/pubmed/{}'.format(r['pmid'])
# Out:
# 0 Combining intracellular antibodies to restore function of mu http://www.ncbi.nlm.nih.gov/pubmed/26174762
# 1 PDL1 Regulation by p53 via miR-34. http://www.ncbi.nlm.nih.gov/pubmed/26577528
# 2 p14(ARF) Prevents Proliferation of Aneuploid Cells by Induci http://www.ncbi.nlm.nih.gov/pubmed/25752701
# 3 Intelligent DNA machine for the ultrasensitive colorimetric  http://www.ncbi.nlm.nih.gov/pubmed/26291961
# 4 Reactivation of p53 by a Cytoskeletal Sensor to Control the  http://www.ncbi.nlm.nih.gov/pubmed/26464464
# 5 Calcitonin Gene-Related Peptide Improves Hypoxia-Induced Inf http://www.ncbi.nlm.nih.gov/pubmed/26430901
# 6 Sevoflurane Preconditioning Confers Neuroprotection via Anti http://www.ncbi.nlm.nih.gov/pubmed/26463923
# 7 Gallic acid induces apoptosis in human cervical epithelial c http://www.ncbi.nlm.nih.gov/pubmed/26059022
# 8 S-Adenosylmethionine Affects ERK1/2 and Stat3 Pathways and I http://www.ncbi.nlm.nih.gov/pubmed/26174106
# 9 Synergistic therapeutic effects of Schiff's base cross-linke http://www.ncbi.nlm.nih.gov/pubmed/26497429
# 10 p53 protein aggregation promotes platinum resistance in ovar http://www.ncbi.nlm.nih.gov/pubmed/25263447
# 11 Reactivating p53 functions by suppressing its novel inhibito http://www.ncbi.nlm.nih.gov/pubmed/26343523
# 12 Inactivation of the p53-KLF4-CEBPA axis in acute myeloid leu http://www.ncbi.nlm.nih.gov/pubmed/26408402
# 13 Mechanisms of p53 degradation. http://www.ncbi.nlm.nih.gov/pubmed/25172038
# 14 TRIM25 has a dual function in the p53/Mdm2 circuit. http://www.ncbi.nlm.nih.gov/pubmed/25728675
# 15 A small peptide derived from p53 linker region can resume th http://www.ncbi.nlm.nih.gov/pubmed/25444901
# 16 Significance of p53 expression in background endometrium in  http://www.ncbi.nlm.nih.gov/pubmed/25788166
# 17 L-GILZ binds p53 and MDM2 and suppresses tumor growth throug http://www.ncbi.nlm.nih.gov/pubmed/25168242
# 18 CP-31398 inhibits the growth of p53-mutated liver cancer cel http://www.ncbi.nlm.nih.gov/pubmed/26250460
# 19 Genome-wide analysis of p53 transcriptional programs in B ce http://www.ncbi.nlm.nih.gov/pubmed/26372730
# 20 Tumor suppressor p53 stole the AKT in hypoxia. http://www.ncbi.nlm.nih.gov/pubmed/25961449
# 21 Mdm2-dependent regulation of p53 expression during long-term http://www.ncbi.nlm.nih.gov/pubmed/25573363
# 22 Hitting cancers' weak spots: vulnerabilities imposed by p53  http://www.ncbi.nlm.nih.gov/pubmed/25960041
# 23 Structure of full-length p53 tumor suppressor probed by chem http://www.ncbi.nlm.nih.gov/pubmed/25728495
# 24 Ellipticine induces apoptosis in T-cell lymphoma via oxidati http://www.ncbi.nlm.nih.gov/pubmed/24898668
